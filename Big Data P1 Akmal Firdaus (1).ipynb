# %% [markdown]
# Dasar PySpark dan Pandas

# %%
from pyspark.sql import SparkSession

# Memulai Spark session
spark = SparkSession.builder.appName("BigDataPractice").getOrCreate()

# Membuat DataFrame sederhana
data = [("Ali", 34, "Musisi", "Main Game", "Laki-laki"),
        ("Budi", 23, "Kuli", "Olahraga", "Laki-laki" ),
        ("Citra", 29, "Guru", "Nyanyi", "Perempuan"),
        ("Dina", 45, "Dokter", "Lari", "Perempuan")]
columns = ["Nama", "Usia", "Pekerjaan", "Hobi", "Gender"]
df = spark.createDataFrame(data, columns)

# Menampilkan DataFrame
df.show()
# Out:
# +-----+----+---------+---------+---------+
# | Nama|Usia|Pekerjaan|     Hobi|   Gender|
# +-----+----+---------+---------+---------+
# |  Ali|  34|   Musisi|Main Game|Laki-laki|
# | Budi|  23|     Kuli| Olahraga|Laki-laki|
# |Citra|  29|     Guru|   Nyanyi|Perempuan|
# | Dina|  45|   Dokter|     Lari|Perempuan|
# +-----+----+---------+---------+---------+

# %% [markdown]
# Latihan 1: Memanipulasi Data dengan PySpark & Melakukan filter penghitung rata-rata, dan pengurutan data menggunakan PySpark.

# %%
from pyspark.sql import SparkSession

# Memulai Spark session
spark = SparkSession.builder.appName("BigDataPractice").getOrCreate()

# Membuat DataFrame sederhana
data = [("Ali", 34, "Musisi", "Main Game", "Laki-laki"),
        ("Budi", 23, "Kuli", "Olahraga", "Laki-laki" ),
        ("Citra", 29, "Guru", "Nyanyi", "Perempuan"),
        ("Dina", 45, "Dokter", "Lari", "Perempuan")]
columns = ["Nama", "Usia", "Pekerjaan", "Hobi", "Gender"]
df = spark.createDataFrame(data, columns)

# Menampilkan DataFrame
df.show()

# Filtering data
df_filtered = df.filter(df['Usia'] > 30)
df_filtered.show()

# Menghitung rata-rata usia
from pyspark.sql.functions import avg
df.groupBy().agg(avg("Usia")).show()

# Mengurutkan data berdasarkan usia
df_sorted = df.orderBy("Usia", ascending=False)
df_sorted.show()
# Out:
# +-----+----+---------+---------+---------+
# | Nama|Usia|Pekerjaan|     Hobi|   Gender|
# +-----+----+---------+---------+---------+
# |  Ali|  34|   Musisi|Main Game|Laki-laki|
# | Budi|  23|     Kuli| Olahraga|Laki-laki|
# |Citra|  29|     Guru|   Nyanyi|Perempuan|
# | Dina|  45|   Dokter|     Lari|Perempuan|
# +-----+----+---------+---------+---------+
#
# +----+----+---------+---------+---------+
# |Nama|Usia|Pekerjaan|     Hobi|   Gender|
# +----+----+---------+---------+---------+
# | Ali|  34|   Musisi|Main Game|Laki-laki|
# |Dina|  45|   Dokter|     Lari|Perempuan|
# +----+----+---------+---------+---------+
#
# +---------+
# |avg(Usia)|
# +---------+
# |    32.75|
# +---------+
#
# +-----+----+---------+---------+---------+
# | Nama|Usia|Pekerjaan|     Hobi|   Gender|
# +-----+----+---------+---------+---------+
# | Dina|  45|   Dokter|     Lari|Perempuan|
# |  Ali|  34|   Musisi|Main Game|Laki-laki|
# |Citra|  29|     Guru|   Nyanyi|Perempuan|
# ...

# %% [markdown]
# Latihan 2: Buat DataFrame menggunakan Pandas:

# %%
import pandas as pd

# Membuat DataFrame Pandas
data_pandas = {"Nama": ["Ali", "Budi", "Citra", "Dina"], "Usia": [34, 23, 29, 45]}
df_pandas = pd.DataFrame(data_pandas)

# Menampilkan DataFrame Pandas
df_pandas
# Out:
#     Nama  Usia
# 0    Ali    34
# 1   Budi    23
# 2  Citra    29
# 3   Dina    45

# %% [markdown]
# Tugas 3 : Modifikasi DataFrame Pandas dengan Menambahkan Kolom baru dan melakukan operas seperti filtering data berdasarkan usia

# %%
import pandas as pd

# Membuat DataFrame Pandas
data_pandas = {"Nama": ["Ali", "Budi", "Citra", "Dina"],
               "Usia": [34, 23, 29, 45],
               "Gender": ["Laki-laki", "Laki-laki", "Perempuan", "Perempuan"]}
df_pandas = pd.DataFrame(data_pandas)

# Menampilkan DataFrame Pandas
df_pandas

# Memfilter data
df_filtered = df_pandas[df_pandas['Usia'] > 30]
df_filtered
# Out:
#    Nama  Usia     Gender
# 0   Ali    34  Laki-laki
# 3  Dina    45  Perempuan

# %% [markdown]
# Latihan 3: Pengguanaan Pandas untuk operasi lebih kompleks

# %%
import pandas as pd

# Membuat DataFrame Pandas
data_pandas = {"Nama": ["Ali", "Budi", "Citra", "Dina"], "Usia": [34, 23, 29, 45]}
df_pandas = pd.DataFrame(data_pandas)

# Membuat DataFrame kedua
data_pandas_2 = {"Nama": ["Ali", "Budi", "Citra", "Dina"], "Pekerjaan": ["Dokter", "Guru", "Insinyur", "Perawat"]}
df_pandas_2 = pd.DataFrame(data_pandas_2)

# Join antara dua DataFrame
df_joined = pd.merge(df_pandas, df_pandas_2, on="Nama")
print(df_joined)

# Menghitung statistik deskriptif
print(df_pandas.describe())

# Plotting Data
import matplotlib.pyplot as plt
df_pandas['Usia'].plot(kind='bar')
plt.show()
# Out:
#     Nama  Usia Pekerjaan
# 0    Ali    34    Dokter
# 1   Budi    23      Guru
# 2  Citra    29  Insinyur
# 3   Dina    45   Perawat
#             Usia
# count   4.000000
# mean   32.750000
# std     9.322911
# min    23.000000
# 25%    27.500000
# 50%    31.500000
# 75%    36.750000
# max    45.000000

# %% [markdown]
# Tugas 4 : Lakukan penggabungan DataFrame dan visualisaikan data dengan Pandas

# %%
import pandas as pd

# Membuat DataFrame Pandas
data_pandas = {"Nama": ["Ali", "Budi", "Citra", "Dina"],
               "Usia": [34, 23, 29, 45]}
df_pandas = pd.DataFrame(data_pandas)


# Frame 2
data_pandas_2 = {"Nama": ["Ali", "Budi", "Citra", "Dina"],
                 "pekerjaan": ["Dokter", "Guru", "Insinyur", "Perawat"]}
df_pandas_2 = pd.DataFrame(data_pandas_2)

# %%
import pandas as pd

# Membuat DataFrame Pandas
data_pandas = {"Nama": ["Ali", "Budi", "Citra", "Dina"],
               "Usia": [34, 23, 29, 45]}
df_pandas = pd.DataFrame(data_pandas)

# Membuat DataFrame Kedua
data_pandas_2 = {"Nama": ["Ali", "Budi", "Citra", "Dina"],
                 "Pekerjaan": ["Dokter", "Guru", "Insinyur", "Perawat"]}
df_pandas_2 = pd.DataFrame(data_pandas_2)

# Join antara dua DataFrame
df_joined = pd.merge(df_pandas, df_pandas_2, on='Nama')

# Plotting data
import matplotlib.pyplot as plt
df_joined.plot(x='Nama', kind='bar')
plt.show()
df_joined
# Out:
#     Nama  Usia Pekerjaan
# 0    Ali    34    Dokter
# 1   Budi    23      Guru
# 2  Citra    29  Insinyur
# 3   Dina    45   Perawat

# %% [markdown]
# Latihan 4: Mengonversi DataFrame antara PySpark dan Pandas Praktik untuk convert DataFrame dari PySpark ke Pandas dan sebaliknya:

# %%
# Mengonversi DataFrame dari PySpark ke Pandas
df_pandas_from_spark = df.toPandas()

# Mengonversi DataFrame dari Pandas ke PySpark
df_spark_from_pandas = spark.createDataFrame(df_pandas)

# Menampilkan DataFrame hasil konversi
df_pandas_from_spark, df_spark_from_pandas.show()

# Menghitung rata-rata usia
df.groupBy().agg(avg("Usia")).show()
# Out:
# +-----+----+
# | Nama|Usia|
# +-----+----+
# |  Ali|  34|
# | Budi|  23|
# |Citra|  29|
# | Dina|  45|
# +-----+----+
#
# +---------+
# |avg(Usia)|
# +---------+
# |    32.75|
# +---------+

# %% [markdown]
#  Konversi Data antara PySpark dan Pandas

# %%
# Mengonversi DataFrame dari PySpark ke Pandas
df_pandas_from_spark = df.toPandas()

# Mengonversi DataFrame dari Pandas ke PySpark
df_spark_from_pandas = spark.createDataFrame(df_pandas)

# Menampilkan DataFrame hasil konversi
df_pandas_from_spark, df_spark_from_pandas.show()
# Out:
# +-----+----+
# | Nama|Usia|
# +-----+----+
# |  Ali|  34|
# | Budi|  23|
# |Citra|  29|
# | Dina|  45|
# +-----+----+
# (    Nama  Usia Pekerjaan       Hobi     Gender
#  0    Ali    34    Musisi  Main Game  Laki-laki
#  1   Budi    23      Kuli   Olahraga  Laki-laki
#  2  Citra    29      Guru     Nyanyi  Perempuan
#  3   Dina    45    Dokter       Lari  Perempuan,
#  None)

# %% [markdown]
# Tugas 6: Gabungkan data dari PySpark dan Pandas, lalu lakukan operasi statistik seperti menghitung nilai maksimum usia

# %%
# Mengonversi DataFrame dari PySpark ke Pandas
df_pandas_from_spark = df.toPandas()

# Mengorversi DataFrame dari Pandas ke PySpark
df_spark_from_pandas = spark.createDataFrame(df_pandas)

# Menampilkan DataFrame hasil konversi
df_pandas_from_spark, df_spark_from_pandas.show()

# Menghitung rata rata usia
from pyspark.sql.functions import max
df.groupBy().agg(max("Usia")).show()
# Out:
# +-----+----+
# | Nama|Usia|
# +-----+----+
# |  Ali|  34|
# | Budi|  23|
# |Citra|  29|
# | Dina|  45|
# +-----+----+
#
# +---------+
# |max(Usia)|
# +---------+
# |       45|
# +---------+
